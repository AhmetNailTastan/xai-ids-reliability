# %% [markdown]
# # RQ2 true pairwise model variation
#
# Computes true 50-model pairwise comparisons, producing 1,225 pairs per dataset/model when SHAP arrays are available.

# %%
from src.model_variation_pairwise import compute_pairwise_variation, summarize_pairwise_records

print(compute_pairwise_variation.__name__)
print(summarize_pairwise_records.__name__)

# %%
# Expected input: one NPZ per dataset/model with one SHAP matrix per trained model instance.
# Example CLI:
# python -m src.model_variation_pairwise --dataset Edge-IIoT --model RF --npz data/edgeiiot_checkpoints/rf_shap_instances.npz
