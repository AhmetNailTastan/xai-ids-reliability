# %% [markdown]
# # DNN/LSTM reproduction
#
# Canonical entry point for neural-model reproduction with CPU-safe device selection.

# %%
from src.train_neural import describe_device

print(describe_device())

# %%
from src.config import DNN_LSTM_CHECKPOINT_DIR

print(f"Checkpoint directory: {DNN_LSTM_CHECKPOINT_DIR}")
