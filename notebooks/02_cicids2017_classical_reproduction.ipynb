# %% [markdown]
# # CIC-IDS-2017 classical reproduction
#
# Canonical entry point for fold-safe classical-model reproduction on CIC-IDS-2017.

# %%
from pathlib import Path
from src.config import RAW_CIC_DIR, VERI_KLASORU, CICIDS2017_CHECKPOINT_DIR, N_SEEDS, N_FOLD

print(f"Expected CIC raw directory: {RAW_CIC_DIR}")
print(f"VERI_KLASORU: {VERI_KLASORU}")
print(f"Checkpoint directory: {CICIDS2017_CHECKPOINT_DIR}")
print(f"Protocol: {N_SEEDS} seeds x {N_FOLD} folds")

# %%
if not RAW_CIC_DIR.exists():
    raise FileNotFoundError(f"Missing raw data directory: {RAW_CIC_DIR}. See data/README.md")

# %%
from src.train_classical import evaluate_model_fold_safe

print("Fold-safe helper ready:", evaluate_model_fold_safe.__name__)
